# %% [markdown]
# # 05d – Data Cleansing: Testing
#
# **Author:** Roberto Chiaiese
# **Project:** CovidReporting Data Warehouse
#
# ##  Overview
# This notebook transforms the COVID-19 testing dataset into the analytical fact table **factTesting**.
# It includes test counts, new cases, positivity rate, and testing rate by country and week.
#
# ## Steps Performed
# 1. **Load data** from `staging.testing`.
# 2. **Clean missing or invalid records** and convert numeric fields.
# 3. **Normalize reporting week** and link it to the date dimension (`dimDate`).
# 4. **Map country codes** to `dimCountry`.
# 5. **Select relevant columns** for analytical purposes.
# 6. **Save final cleansed data** to populate the **factTesting** table.
#
# ## Output Table
# **factTesting**
# - `test_id`,`country_key`, `date_id`, `new_cases`, `tests_done`, `testing_rate`, `positivity_rate`, `source`

# %%
import pandas as pd
import numpy as np

# %%
# read the file from github and create a dataframe
df = pd.read_csv('/home/jovyan/datawarehouse/staging_layer/dataset/testing.csv')
df.head()
# Out:
#    country country_code year_week  new_cases  tests_done  population  \
# 0  Austria           AT  2020-W15       2041       12339     8858775
# 1  Austria           AT  2020-W16        855       58488     8858775
# 2  Austria           AT  2020-W17        472       33443     8858775
# 3  Austria           AT  2020-W18        336       26598     8858775
# 4  Austria           AT  2020-W19        307       42153     8858775
#
#    testing_rate  positivity_rate testing_data_source
# 0    139.285624        16.541049  Manual webscraping
# 1    660.226724         1.461838  Manual webscraping
# 2    377.512692         1.411357  Manual webscraping
# 3    300.244673         1.263253     Country website
# 4    475.833284         0.728299     Country website

# %%
lookup_country = pd.read_csv('/home/jovyan/datawarehouse/lookup/country_lookup.csv')

# %%
# upload dimDate to create the fact table for the testing

df_merged = pd.merge(df, lookup_country, on='country', how='left')
df_merged.head()
# Out:
#    country country_code year_week  new_cases  tests_done  population_x  \
# 0  Austria           AT  2020-W15       2041       12339       8858775
# 1  Austria           AT  2020-W16        855       58488       8858775
# 2  Austria           AT  2020-W17        472       33443       8858775
# 3  Austria           AT  2020-W18        336       26598       8858775
# 4  Austria           AT  2020-W19        307       42153       8858775
#
#    testing_rate  positivity_rate testing_data_source country_code_2_digit  \
# 0    139.285624        16.541049  Manual webscraping                   AT
# 1    660.226724         1.461838  Manual webscraping                   AT
# 2    377.512692         1.411357  Manual webscraping                   AT
# 3    300.244673         1.263253     Country website                   AT
# 4    475.833284         0.728299     Country website                   AT
#
#   country_code_3_digit continent  population_y
# 0                  AUT    Europe       8858775
# 1                  AUT    Europe       8858775
# 2                  AUT    Europe       8858775
# 3                  AUT    Europe       8858775
# 4                  AUT    Europe       8858775

# %%
df_merged = df_merged[['country','country_code_2_digit','country_code_3_digit','year_week','new_cases','tests_done','population_x','testing_rate','positivity_rate','testing_data_source']]

# %%
df_merged.head()
# Out:
#    country country_code_2_digit country_code_3_digit year_week  new_cases  \
# 0  Austria                   AT                  AUT  2020-W15       2041
# 1  Austria                   AT                  AUT  2020-W16        855
# 2  Austria                   AT                  AUT  2020-W17        472
# 3  Austria                   AT                  AUT  2020-W18        336
# 4  Austria                   AT                  AUT  2020-W19        307
#
#    tests_done  population_x  testing_rate  positivity_rate testing_data_source
# 0       12339       8858775    139.285624        16.541049  Manual webscraping
# 1       58488       8858775    660.226724         1.461838  Manual webscraping
# 2       33443       8858775    377.512692         1.411357  Manual webscraping
# 3       26598       8858775    300.244673         1.263253     Country website
# 4       42153       8858775    475.833284         0.728299     Country website

# %%
# rename the columns
df_merged = df_merged.rename(columns={'year_week':'reported_year_week','population_x':'population'})

# %%
df_merged.head()
# Out:
#    country country_code_2_digit country_code_3_digit reported_year_week  \
# 0  Austria                   AT                  AUT           2020-W15
# 1  Austria                   AT                  AUT           2020-W16
# 2  Austria                   AT                  AUT           2020-W17
# 3  Austria                   AT                  AUT           2020-W18
# 4  Austria                   AT                  AUT           2020-W19
#
#    new_cases  tests_done  population  testing_rate  positivity_rate  \
# 0       2041       12339     8858775    139.285624        16.541049
# 1        855       58488     8858775    660.226724         1.461838
# 2        472       33443     8858775    377.512692         1.411357
# 3        336       26598     8858775    300.244673         1.263253
# 4        307       42153     8858775    475.833284         0.728299
#
#   testing_data_source
# 0  Manual webscraping
# 1  Manual webscraping
# 2  Manual webscraping
# 3     Country website
# 4     Country website

# %%
#drop country and country_code_3_digit columns and rename tge index and the country_code_2_digit columns
df_merged = df_merged.drop(columns=['country','country_code_3_digit','Unnamed: 0']).reset_index().rename(columns={'country_code_2_digit':'country_id', 'index':'test_id'})

# %%
#convert the data to create a testing id made by the country + year + week of the year
df_merged['year'] = df['reported_year_week'].str[0:4].astype("Int64")
df_merged['week_of_year'] = df['reported_year_week'].str[6:8].astype("Int64")
new_df = df_merged.groupby('test_id').min('date_id').reset_index()
new_df['test_id'] = new_df['country_id'] + new_df['date_id'].astype('str')

# %%
new_df = df_merged[['test_id','country_id','date_id','new_cases','tests_done','testing_rate', 'positivity_rate','year','week_of_year', 'year_week','testing_data_source']]

# %%
new_df.to_csv('/home/jovyan/datawarehouse/core_layer/processed/factTesting.csv', index=False)
